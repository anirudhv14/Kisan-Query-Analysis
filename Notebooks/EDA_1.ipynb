# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Using cached pyspark-3.2.0.tar.gz (281.3 MB)
# Collecting py4j==0.10.9.2
#   Using cached py4j-0.10.9.2-py2.py3-none-any.whl (198 kB)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py): started
#   Building wheel for pyspark (setup.py): still running...
#   Building wheel for pyspark (setup.py): still running...
#   Building wheel for pyspark (setup.py): still running...
#   Building wheel for pyspark (setup.py): still running...
#   Building wheel for pyspark (setup.py): still running...
#   Building wheel for pyspark (setup.py): still running...
#   Building wheel for pyspark (setup.py): still running...
#   Building wheel for pyspark (setup.py): still running...
#   Building wheel for pyspark (setup.py): still running...
#   Building wheel for pyspark (setup.py): still running...
#   Building wheel for pyspark (setup.py): finished with status 'done'
#   Created wheel for pyspark: filename=pyspark-3.2.0-py2.py3-none-any.whl size=281805913 sha256=ae42c4a65f80382e9de6fc202498dba4c3719b1505a64a6dc60c1d2ae71a3e49
#   Stored in directory: c:\users\aniru\appdata\local\pip\cache\wheels\2f\f8\95\2ad14a4614b4a9f645ee928fbbd057b1b254c67adb494c9a58
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.2 pyspark-3.2.0
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\aniru\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import os
from datetime import datetime
from dateutil import parser
from pyspark.sql import SparkSession

# %%
os.chdir('..')

# %%
filename = 'Data\\csv\\Kerala.csv'

# %%
data_m = pd.read_csv(filename)
data_m
# Out:
#       Season        Sector               Category      Crop  \
# 0        NaN  HORTICULTURE             Vegetables    Others
# 1        NaN  HORTICULTURE  Condiments and Spices    Nutmeg
# 2        NaN  HORTICULTURE       Plantation Crops   Coconut
# 3        NaN  HORTICULTURE             Vegetables  Mushroom
# 4        NaN  HORTICULTURE  Condiments and Spices    Nutmeg
# ...      ...           ...                    ...       ...
# 95395    NaN   AGRICULTURE                 Others    Others
# 95396    NaN  HORTICULTURE       Plantation Crops   Coconut
# 95397    NaN  HORTICULTURE                 Fruits    Papaya
# 95398    NaN   AGRICULTURE                 Others    Others
# 95399    NaN   AGRICULTURE                 Others    Others
#
#                        QueryType                             QueryText  \
# 0                              0                          subsidy loan
# 1                              0        nut meg fertilizer application
# 2                              0               coconut button shedding
# 3                              0         mushroom cultivation-training
# 4                              0                          nut meg drop
# ...                          ...                                   ...
# 95395         Government Schemes             Govt schemes for farmers.
# 95396       \tPlant Protection\t           Button shedding in coconut
# 95397       \tPlant Protection\t              Fungal disease in Papaya
# 95398  Agriculture Mechanization  Purchase of agricultural machines \n
# 95399         Government Schemes               PM KISAN related query.
#
#                                                   KccAns StateName  \
# 0                            contact nabard-0483 2734084    KERALA
# 1                    apply potash-2 kg per tree per year    KERALA
# 2                   apply borax 250 gm per palm per year    KERALA
# 3                              contact KVK -0479 2270495    KERALA
# 4      apply borax 250 gm per plant per year( in seve...    KERALA
# ...                                                  ...       ...
# 95395  --Recommended that various schemes are pm kisa...    KERALA
# 95396  Recommended to give 100g borax per palm per ye...    KERALA
# 95397  Recommended to give copper oxy chloride 2g per...    KERALA
# 95398  Suggested to register in SMAM ( Sub Mission on...    KERALA
# 95399  Recommended  SOBHA K G\nFather Name: K SADASIV...    KERALA
#
#       DistrictName       BlockName                CreatedOn
# 0        ALAPPUZHA     KANJIKKUZHY      2013-04-02T17:08:34
# 1        ALAPPUZHA    AMBALAPPUZHA      2013-04-02T17:33:32
# 2        ALAPPUZHA   THYCATTUSSERY      2013-04-04T10:52:07
# 3        ALAPPUZHA   THYCATTUSSERY      2013-04-04T10:53:47
# 4        ALAPPUZHA           ARYAD      2013-04-04T11:18:09
# ...            ...             ...                      ...
# 95395   TRIVANDRUM     KAZHAKUTTAM   2021-09-24T18:08:54.71
# 95396   TRIVANDRUM     KAZHAKUTTAM  2021-09-25T13:13:57.963
# 95397   TRIVANDRUM         VARKALA  2021-09-27T10:03:47.577
# 95398   TRIVANDRUM           NEMOM   2021-09-29T10:57:09.12
# 95399   TRIVANDRUM  CHIRAYINKEEZHU  2021-09-29T12:10:02.153
#
# [95400 rows x 11 columns]

# %%
ss = data_m['CreatedOn']
parsedDate = [parser.parse(i) for i in ss]

# %%
data_m['CreatedOn'] = parsedDate

# %%
data_m
# Out:
#       Season        Sector               Category      Crop  \
# 0        NaN  HORTICULTURE             Vegetables    Others
# 1        NaN  HORTICULTURE  Condiments and Spices    Nutmeg
# 2        NaN  HORTICULTURE       Plantation Crops   Coconut
# 3        NaN  HORTICULTURE             Vegetables  Mushroom
# 4        NaN  HORTICULTURE  Condiments and Spices    Nutmeg
# ...      ...           ...                    ...       ...
# 95395    NaN   AGRICULTURE                 Others    Others
# 95396    NaN  HORTICULTURE       Plantation Crops   Coconut
# 95397    NaN  HORTICULTURE                 Fruits    Papaya
# 95398    NaN   AGRICULTURE                 Others    Others
# 95399    NaN   AGRICULTURE                 Others    Others
#
#                        QueryType                             QueryText  \
# 0                              0                          subsidy loan
# 1                              0        nut meg fertilizer application
# 2                              0               coconut button shedding
# 3                              0         mushroom cultivation-training
# 4                              0                          nut meg drop
# ...                          ...                                   ...
# 95395         Government Schemes             Govt schemes for farmers.
# 95396       \tPlant Protection\t           Button shedding in coconut
# 95397       \tPlant Protection\t              Fungal disease in Papaya
# 95398  Agriculture Mechanization  Purchase of agricultural machines \n
# 95399         Government Schemes               PM KISAN related query.
#
#                                                   KccAns StateName  \
# 0                            contact nabard-0483 2734084    KERALA
# 1                    apply potash-2 kg per tree per year    KERALA
# 2                   apply borax 250 gm per palm per year    KERALA
# 3                              contact KVK -0479 2270495    KERALA
# 4      apply borax 250 gm per plant per year( in seve...    KERALA
# ...                                                  ...       ...
# 95395  --Recommended that various schemes are pm kisa...    KERALA
# 95396  Recommended to give 100g borax per palm per ye...    KERALA
# 95397  Recommended to give copper oxy chloride 2g per...    KERALA
# 95398  Suggested to register in SMAM ( Sub Mission on...    KERALA
# 95399  Recommended  SOBHA K G\nFather Name: K SADASIV...    KERALA
#
#       DistrictName       BlockName               CreatedOn
# 0        ALAPPUZHA     KANJIKKUZHY 2013-04-02 17:08:34.000
# 1        ALAPPUZHA    AMBALAPPUZHA 2013-04-02 17:33:32.000
# 2        ALAPPUZHA   THYCATTUSSERY 2013-04-04 10:52:07.000
# 3        ALAPPUZHA   THYCATTUSSERY 2013-04-04 10:53:47.000
# 4        ALAPPUZHA           ARYAD 2013-04-04 11:18:09.000
# ...            ...             ...                     ...
# 95395   TRIVANDRUM     KAZHAKUTTAM 2021-09-24 18:08:54.710
# 95396   TRIVANDRUM     KAZHAKUTTAM 2021-09-25 13:13:57.963
# 95397   TRIVANDRUM         VARKALA 2021-09-27 10:03:47.577
# 95398   TRIVANDRUM           NEMOM 2021-09-29 10:57:09.120
# 95399   TRIVANDRUM  CHIRAYINKEEZHU 2021-09-29 12:10:02.153
#
# [95400 rows x 11 columns]

# %%
data_m.describe()
# Out:
# <ipython-input-9-491d8512b99a>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data_m.describe()
#         Season        Sector Category    Crop             QueryType  \
# count       64         95400    95400   95400                 95400
# unique       3             6       23     327                    98
# top     KHARIF  HORTICULTURE   Others  Others  \tPlant Protection\t
# freq        25         63741    23907   24535                 37433
# first      NaN           NaN      NaN     NaN                   NaN
# last       NaN           NaN      NaN     NaN                   NaN
#
#           QueryText                                             KccAns  \
# count         95400                                              93249
# unique        43555                                              57432
# top     pest attack  Animal husbandry contact \r\nPlease contact 18...
# freq           1477                                               1053
# first           NaN                                                NaN
# last            NaN                                                NaN
#
#        StateName DistrictName BlockName                   CreatedOn
# count      95400        95400     95400                       95400
# unique         1           10       123                       92761
# top       KERALA    ERNAKULAM      0            2013-01-14 08:03:00
# freq       95400        16212      7420                          39
# first        NaN          NaN       NaN         2013-01-01 08:45:00
# last         NaN          NaN       NaN  2021-11-11 21:51:26.277000

# %% [markdown]
# ## PySpark

# %%
spark = SparkSession.builder.getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-409cf9706472> in <module>
# ----> 1 spark = SparkSession.builder.getOrCreate()
#
# c:\users\aniru\appdata\local\programs\python\python39\lib\site-packages\pyspark\sql\session.py in getOrCreate(self)
#     226                             sparkConf.set(key, value)
#     227                         # This SparkContext may be an existing one.
# --> 228                         sc = SparkContext.getOrCreate(sparkConf)
#     229                     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     230                     # by all sessions.
#
# c:\users\aniru\appdata\local\programs\python\python39\lib\site-packages\pyspark\context.py in getOrCreate(cls, conf)
#     390         with SparkContext._lock:
#     391             if SparkContext._active_spark_context is None:
# --> 392                 SparkContext(conf=conf or SparkConf())
#     393             return SparkContext._active_spark_context
#     394
#
# c:\users\aniru\appdata\local\programs\python\python39\lib\site-packages\pyspark\context.py in __init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)
#     142                 " is not allowed as it is a security risk.")
#     143
# --> 144         SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     145         try:
#     146             self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#
# c:\users\aniru\appdata\local\programs\python\python39\lib\site-packages\pyspark\context.py in _ensure_initialized(cls, instance, gateway, conf)
#     337         with SparkContext._lock:
#     338             if not SparkContext._gateway:
# --> 339                 SparkContext._gateway = gateway or launch_gateway(conf)
#     340                 SparkContext._jvm = SparkContext._gateway.jvm
#     341
#
# c:\users\aniru\appdata\local\programs\python\python39\lib\site-packages\pyspark\java_gateway.py in launch_gateway(conf, popen_kwargs)
#     103             # Wait for the file to appear, or for the process to exit, whichever happens first.
#     104             while not proc.poll() and not os.path.isfile(conn_info_file):
# --> 105                 time.sleep(0.1)
#     106
#     107             if not os.path.isfile(conn_info_file):
#
# KeyboardInterrupt:
